# %% [markdown]
# <h1 align = "center"><u> Banking Telemarketting Project</h1>
# <hr>

# %% [markdown]
# <h2 align = "center">INTRODUCTION</h2>
# <br>
# <p  style="text-align:justify">
# Data science, machine learning and analytics are growing at an astronomical rate because the humongous amounts of the data that is being generated by the companies, and the companies  are now looking for professionals who can sift through the goldmine of data and help them drive swift business decisions efficiently. By examining large amounts of data, it is possible to uncover hidden patterns and trends. <br><br>
# In this project we have the data that relates to the marketing campaign of a Portuguese banking institution. It provides assessment (data) of a bank’s marketing division, to sell long-term (fixed) deposits to clients based on their socio-economic indicators, like their marital status, type of job, age, etc.The aim of the project is to make use of machine learning techniques to build an effective predictive-analytical model which can forecast, whether a client is likely to subscribe to a long term (fixed) deposit account with the bank or not. Since the resulting variable is either yes or no and we are using more than two variables in our data to predict that, so our problem is a multivariate binary classification problem.</p>

# %% [markdown]
# ![Image error](img/Introduction-image.jpg)

# %% [markdown]
# Figure 1: Overview of the problem<br>
# <hr><br>

# %% [markdown]
# <h2 align = "center">BACKGROUND</h2><br>

# %% [markdown]
# <p  style="text-align:justify">
# Machine learning is a subset of artificial intelligence in the field of computer science that often uses statistical techniques to give computers the ability to "learn" (i.e., progressively improve performance on a specific task) with data, without being explicitly programmed [1]. Machine learning deals with the study and construction of the algorithms and helps in finding the patterns and trends in the data and simultaneously analyze the data. Such an approach overcomes following the traditional approach of programming which was very static in nature by making data-driven decisions and predictions. Various fields wherein the algorithms which are explicitly programmed are infeasible such as email filtering, intruder detection, optical character recognition (OCR), computer vision, recommending new products to the users or customer segmentation etc, machine learning algorithms play a vital role.<br><br>
# Data analysis is a process of inspecting, cleansing, transforming, and modeling data with the only purpose of discovering useful information, informing conclusions, and supporting decision-making. Data analysis has multiple facets and approaches, encompassing diverse techniques under a variety of names while being used in different business, science, and social science domains. In Data analytics, machine learning can be employed to formulate complex models and algorithms that help in making prediction; when this is put into commercial use, this is known as predictive analytics. The core of predictive analytics relies on capturing relationships between explanatory variables and the predicted variables from past occurrences, and exploiting them to predict the unknown outcome.This helps us in producing authentic results, and also assist in revealing hidden insights by grasping the trends and relationships in the data. As we already said that machine learning can be used in developing models which will help in making predictions. Machine learning is being classified into three broad categories as shown in the figure.</p>

# %% [markdown]
# ![Image error](img/Backgrounf-image.jpg)

# %% [markdown]
# Figure 2 :Machine Learning Algorithms
# <br><hr>

# %% [markdown]
# <h4>A)  Supervised Learning</h4><br>
# <p  style="text-align:justify">
# Supervised learning is a process in which an algorithm learns from example data and associated correct answers, so that it will be able to predict the correct response when new examples are being fed to the model. This approach is quite similar to the approach of human being learning under the supervision of a teacher, wherein the teacher provides good examples for the student to memorize, and the student then derives general rules from these specific examples. We have two distinct problems over in here, the regression problem, where the target variable is numeric or continuous in nature and the classification problem, where the target variable is discrete or qualitative in nature such as class or tag.
# </p><br>
#
# <h4>B)  Unsupervised Learning</h4><br>
# <p  style="text-align:justify">
# Unsupervised algorithms are the family of machine learning algorithms which are mainly used in pattern detection and descriptive modeling. In this approach, we do not have labels associated with the data. We try to group together distinct objects based on the similar feature they have. The algorithm finds the patterns in the data by itself. They are quite useful in getting insights from the data. Some recommendation systems, where we get the suggestion about the new products are based on the past history of the products we have queried and bought, these types of systems are based on this type of learning.
# </p><br>
#
# <h4>C)  Reinforcement Learning</h4><br>
# <p  style="text-align:justify">
# Reinforced Learning algorithm aims at using observations gathered from the interaction with the environment to take actions that would maximize the reward or minimize the risk. Reinforcement learning algorithm (called the agent) continuously learns from the environment in an iterative fashion. In the process, the agent learns from its experiences of the environment until it explores the full range of possible states. Reinforcement learning allows machines and software agents to automatically determine the ideal behavior within a specific context, in order to maximize its performance. Simple reward feedback is required for the agent to learn its behavior, this is known as the reinforcement signal.
# </p><br>

# %% [markdown]
# ![Image error](img/Machine-Learning-Subtypes.jpg)

# %% [markdown]
# Figure 3 : Machine Learning Subtypes <br><hr><br>

# %% [markdown]
# <h2 align = "center">FLOW DIAGRAM OF MACHINE LEARNING PROCESS</h2><br>

# %% [markdown]
# <p  style="text-align:justify">
#     We have divided this project into various parts which will serve various purpose. The first step involves Data preprocessing which is the process of converting a raw data into such a format so that it can be analysed.This step will occur only once, as we do not need to clean the data again and again. Followed by the data splitting method which involved the way we split our data whether we use train test split method or k-fold method. After selecting the appropriate data splitting method we select machine learning algorithm and fit the model and tune its various parameters which comes under the model fitting block. After that we evaluate our model by comparing the predicted values to the actual values in the test data. We will redo these steps again and again till we get desired results.</p>

# %% [markdown]
# ![Image error](img/Flow-Diagram.jpg)

# %% [markdown]
# Figure 4 : Flow diagram of a Machine Learning process<br><hr><br>

# %% [markdown]
# <h3>Loading Data</h3>
# <p  style="text-align:justify">
#     We will first import the pandas package and then load the data into a dataframe <b>'df'</b> using the <b>read_csv()</b> method of pandas.

# %%
import pandas as pd
import numpy as np
df = pd.read_csv("/home/future/Documents/Project data set/bank-additional/bank-additional/bank-additional-full.csv", delimiter = ";")

# %% [markdown]
# Lets take a lok at our dataset using __df.head()__ method, which which display the first five rows of our dataset.

# %% [markdown]
# ----
# # A Tour of Dataset
# ----

# %% [markdown]
# The dataset has been obtained from the UCI Machine Learning repository. The UCI Machine Learning Repository is a collection of databases, domain theories, and data generators that are used by the machine learning community for the empirical analysis of machine learning algorithms. The archive was created as an ftp archive in 1987 by David Aha and fellow graduate students at UC Irvine. Since that time, it has been widely used by students, educators, and researchers all over the world as a primary source of machine learning data sets. As an indication of the impact of the archive, UCI has been cited over 1000 times, making it one of the top 100 most cited repositories in all of computer science.
#
# <p>The data set for this project contains about 41,188 instances and  around 20 features. We have cleaned the data using Pandas. We have put few instances of the data when it was in its raw format below:

# %%
print(df.shape)
df.sample(5)
# Out:
# (41175, 21)
#        age         job   marital            education  default housing loan  \
# 14595   29  management    single          high.school       no      no  yes
# 10479   36  technician   married  professional.course  unknown      no   no
# 2666    52  technician   married          high.school       no     yes  yes
# 9214    41     unknown   married             basic.6y       no      no  yes
# 40714   84     retired  divorced              unknown  unknown      no   no
#
#          contact month day_of_week ...   campaign  pdays  previous  \
# 14595   cellular   jul         tue ...          4    999         0
# 10479  telephone   jun         tue ...         10    999         0
# 2666   telephone   may         wed ...          2    999         0
# 9214   telephone   jun         fri ...          4    999         0
# 40714   cellular   sep         tue ...          1      3         2
#
#           poutcome emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  \
# ...

# %%
import matplotlib.pyplot as plt
import pandas as pd
from pandas.tools.plotting import table
plt.figure(figsize=(80, 98))
ax = plt.subplot(111, frame_on=False) # no visible frame
ax.xaxis.set_visible(False)  # hide the x axis
ax.yaxis.set_visible(False)  # hide the y axis


#table(ax, df.sample())  # where df is your data frame
table(ax, df.sample(10), rowLabels=['']*10, loc='center')
plt.savefig('mytable.png')

# %% [markdown]
# We will categorize the Features into five distinct classes:
# - Demographic Information of Client (CD)
# - Financial Information of Client (CF)
# - Items related to Current Marketting Campaign (CM)
# - Items related to a Prior Marketing Campaign (PM)
# - Social Economic situation (SE)
#
# <p> The Table shown below gives a description of the data attributes.The 'Attribute' column contains the name of the feature follwed by its 'Description'. The 'type' column tells us wether the data is categorical (C) or numerical (N) followed by its category which we have stated above. The last column tells us about the possible values contained in each feature.</p>
#
# ![Image error](img/table-data-attributes.png)

# %% [markdown]
# ----
# ## Explanatory Data Analysis Before Preprocessing
# ----
# <p  style="text-align:justify">
# Before preprocessing any form of  data, data has to be understood at the first stage by using statistical techniques and visualization. For any business or individual which want to first get a sense of data quality and major characteristics such as central tendency ( mean, median, standard deviation, mode etc) and distribution (histogram, scatter plots etc)</p>
#
# The __describe()__ gives generates descriptive statistics that summarize the central tendency, dispersion and shape of a dataset’s distribution, excluding NaN values.<br>
#
# For numeric data, the result’s index will include count, mean, std, min, max as well as lower, 50 and upper percentiles. By default the lower percentile is 25 and the upper percentile is 75. The 50 percentile is the same as the median.<br>
#
# For object data, the result’s index will include count, unique, top, and freq. The top is the most common value. The freq is the most common value’s frequency. Timestamps also include the first and last items.

# %%
df_desc = df.describe(include='all')
df_desc = df_desc.T

# %%
df_desc.to_html('table.html')

# %% [markdown]
# Now let us take a look ath the data type of each of the feature by using __df.dtypes__ attribute of Pandas.

# %%
df_desc = pd.DataFrame(df.dtypes)
df_desc.to_html('table.html')

# %% [markdown]
# There are 11 categorical variables (including target variable 'y') and 10 numerical variables. Now, we will create five different variables based on the categorization as discussed above.

# %%
c_demog_ftr = ['age', 'job', 'marital', 'education']
c_financial_ftr = ['default', 'housing', 'loan','y'] 
curr_mrkt_ftr = ['contact', 'month', 'day_of_week', 'duration', 'campaign']
prior_mrkt_ftr = ['pdays','previous', 'poutcome']
socio_ecnomic_ftr = ['emp.var.rate', 'cons.price.idx','cons.conf.idx', 'euribor3m', 'nr.employed']

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

total_cols = float(len(df.columns.values))

labels = ['Clients demographic information(CD)', 'Clients financial information(CF)',
          "Items related to Current Marketting Campaign (CM)","Items related to a Prior Marketing Campaign (PM)",
          "Social Economic situation (SE)"]
sizes = [len(c_demog_ftr)/total_cols, len(c_financial_ftr)/total_cols, len(curr_mrkt_ftr)/total_cols, 
           len(prior_mrkt_ftr)/total_cols, len(socio_ecnomic_ftr)/total_cols ]

colors = ['gold', 'yellowgreen', 'lightcoral', 'lightskyblue']
explode = (0, 0, 0.1, 0,0.1)  # explode 1st slice
 
# Plot
plt.pie(sizes, explode=explode, labels=labels, colors=colors,
        autopct='%1.1f%%', shadow=True)
 
plt.axis('equal')

plt.savefig('donut.png')
#plt.show()

# %% [markdown]
# The pie chart above shows the data contribution of this data as categories.
#
# ----

# %%
def form_table(df,feature):
    tmp = df[feature].value_counts()
    tmp = pd.DataFrame(tmp)
    tmp.index.names = ['Attribute Value']
    tmp.columns= ['Number of Occurences']
    return tmp

# %% [markdown]
# <p  style="text-align:justify">
#     We will first do that for the categorical variables, we will first fetch the names of the categorical variables in cat_vars followed by the function wih thich we will be able to draw the countplot of each categorical feature. </p>

# %%
cat_vars = df.select_dtypes(include=['object']).columns.tolist()

def draw_countplot(df,feature):
    fig , (ax1, ax2) = plt.subplots(1,2,figsize=(14,6))
    #plt.setp( ax1.xaxis.get_majorticklabels(), rotation=15 )
    sns.countplot(y=feature, data = df , hue = 'y', palette='Set1',ax=ax2)
    sns.countplot(x=feature, data = df , palette='Set2',ax=ax1)
    plt.title(feature)
    plt.savefig(str(col)+'_chart.png')

# %% [markdown]
# The magic code written below disables the scrolling when the plots are displayed

# %%
# %%javascript
# IPython.OutputArea.prototype._should_scroll = function(lines) {
#     return false;
# }

# %%
for col in cat_vars:
    plt.rcParams["font.weight"] = "bold"
    plt.rcParams["axes.labelweight"] = "bold"
    draw_countplot(df,col)
    plt.title(col)
    plt.tight_layout()

# %% [markdown]
# ----
# Similarly for the numeric variables, we will first fetch the numerical data into num_var variable and then draw the distplot to get an idea of the data distribution.

# %%
num_var = df.select_dtypes(exclude=['object']).columns.tolist()

def draw_distplot(df,feature):
    fig , (ax1, ax2) = plt.subplots(1,2,figsize=(14,6))
    sns.set(palette='Set1')
    sns.distplot(df[df.y == 'no'][feature],label='no',ax = ax1)
    sns.distplot(df[df.y == 'yes'][feature],label='yes',ax = ax1)
    
    ax1.legend()
    ax2 = plt.hist(df[feature])
    plt.savefig(str(col)+'_chart.png')
    #plt.show()

# %%
def print_feat(col):
    print('mean no followed by yes: ',df[df.y == 'no'][col].mean() , df[df.y == 'yes'][col].mean())
    print('std no followed by yes: ',df[df.y == 'no'][col].std() , df[df.y == 'yes'][col].std())
    print('median no followed by yes: ',df[df.y == 'no'][col].median() , df[df.y == 'yes'][col].median())

# %%
print_feat('age')
# Out:
# ('mean no followed by yes: ', 39.90913818112154, 40.9018550474547)
# ('std no followed by yes: ', 9.895889627909195, 13.831754844604845)
# ('median no followed by yes: ', 38.0, 37.0)

# %%
for col in num_var:
    plt.rcParams["font.weight"] = "bold"
    plt.rcParams["axes.labelweight"] = "bold"
    draw_distplot(df,col)
    plt.title(col)
    plt.tight_layout()
# Out:
# /usr/lib/python2.7/dist-packages/scipy/stats/stats.py:1857: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# <hr><br><h3>DATA PREPROCESSING</h3><br>
# <p  style="text-align:justify">
# Data preprocessing is the important step in actual data analytics and aims at making sure that data is ready to be analysed. Data-gathering methods are often loosely controlled, resulting in out-of-range values (e.g., Income: −100), impossible data combinations (e.g., Sex: Male, Pregnant: Yes), missing values, etc. Analyzing data that has not been carefully screened for such problems can produce misleading results. Thus, the representation and quality of data is first and foremost before running an analysis. Often, data preprocessing is the most important phase of a machine learning project.If there is much irrelevant and redundant information present or noisy and unreliable data, then knowledge data goes through a series of steps during preprocessing:
#     </p>

# %% [markdown]
# - Data Cleaning: Data is cleansed through processes such as filling in missing values, smoothing the noisy data, or resolving the inconsistencies in the data.
# - Data Integration: Data with different representations are put together and conflicts within the data are resolved.
# - Data Transformation: Data is normalized, aggregated and generalized.
# - Data Reduction: This step aims to present a reduced representation of the data.
# - Data Discretization: Involves the reduction of a number of values of a continuous attribute by dividing the range of attribute intervals.

# %% [markdown]
# <p  style="text-align:justify">
# Data preparation and filtering steps can take considerable amount of processing time. Data pre-processing includes cleaning, Instance selection, normalization, transformation, feature extraction and selection, etc. The product of data preprocessing is the final training set.</p>

# %% [markdown]
# ![Image error](img/Data-preprocessing.jpg)

# %% [markdown]
# Figure 5: Data Preprocessing <br><hr><br>

# %% [markdown]
# <h4>A)   Data Cleaning:</h4>
# <p  style="text-align:justify">
# Missing values may hinder our further analysis. So, how do we identify all those missing values and deal with them? Some of the approaches for working with missing data is :<br>
# 1. Identify missing data<br>
# 2. Deal with missing data<br>
# 3. Correct data format<br>
#
# </p>

# %% [markdown]
# <h5> 1) Identify missing data</h5>
# <p  style="text-align:justify">
# In the dataset, missing data may be in the form of question mark "?", "NaN" , blank cells, or sometimes "unknown" is written over those places where the data is missing. The primary job is to identify the missing values wether they are there or not. In order to accomplish this we use the methods given below:
#    </p>

# %%
#We will now use the value_counts() method for each of them
for i in cat_vars:
    print(str(i).upper() + " :\n")
    print (df[i].value_counts())
    print ("")
# Out:
# JOB :
#
# admin.           10420
# blue-collar       9253
# technician        6742
# services          3969
# management        2924
# retired           1714
# entrepreneur      1456
# self-employed     1421
# housemaid         1059
# unemployed        1013
# student            874
# unknown            330
# Name: job, dtype: int64
#
# MARITAL :
#
# married     24919
# single      11566
# divorced     4610
# unknown        80
# Name: marital, dtype: int64
#
# EDUCATION :
#
# university.degree      12164
# high.school             9514
# basic.9y                6045
# professional.course     5237
# basic.4y                4175
# basic.6y                2292
# unknown                 1730
# illiterate                18
# Name: education, dtype: int64
#
# DEFAULT :
#
# no         32575
# unknown     8597
# yes            3
# Name: default, dtype: int64
#
# HOUSING :
#
# yes        21567
# no         18618
# unknown      990
# Name: housing, dtype: int64
#
# LOAN :
#
# no         33938
# ...

# %% [markdown]
# <p  style="text-align:justify">
# As we can see that there are various features in the data which contains an unknown value. The Features in our data which contain unknown values are "education","job" , "housing", "loan", "default", "marital". As far as their importance is considered we have, 'education', 'job', 'housing', and 'loan' which play a vital role. Because the total number of entries for an unknown value in the marital is very low and the unknown for 'default' variable maybe because of the reason that the customer is not ready to give away all the data required by the bank employee. Hence, unknown value in default feature is a separate value.
# </p>

# %% [markdown]
# <br>We will first start by Grouping the values in the categorical features as :

# %%
#Grouping Education Feature
df_basic_ed = df[(df.education == 'basic.4y') | (df.education == 'basic.6y') | (df.education == 'illiterate')]
df_mid_ed = df[(df.education == 'basic.9y') | (df.education == 'high.school')]
df_degree_ed = df[(df.education == 'professional.course') | (df.education == 'university.degree')]
        
df.loc[df_basic_ed.index, 'education'] = 'Basic'
df.loc[df_mid_ed.index, 'education'] = 'Mid'
df.loc[df_degree_ed.index, 'education'] = 'Degree'

# %% [markdown]
# So now we have Four unique values for education only after segmentation as shown below.

# %%
df['education'].unique()
# Out:
# array(['Basic', 'Mid', 'Degree', 'unknown'], dtype=object)

# %% [markdown]
# We will do the similar thing for the job Feature

# %%
#Grouping job variable
df_unskilled = df[(df.job == 'blue-collar') | (df.job == 'housemaid')]
df_service = df[(df.job == 'admin.') | (df.job == 'services') | (df.job == 'technician')]
df_professional = df[(df.job == 'entrepreneur') | (df.job == 'self-employed') | (df.job == 'management')]
df_student = df[(df.job == 'student')]
df_retired = df[(df.job == 'retired')]
df_unemployed = df[(df.job == 'unemployed')]      
    
df.loc[df_unskilled.index, 'job'] = 'Unskilled'
df.loc[df_service.index, 'job'] = 'Service'
df.loc[df_professional.index, 'job'] = 'Professional'
df.loc[df_student.index, 'job'] = 'Student'
df.loc[df_retired.index, 'job'] = 'Retired'
df.loc[df_unemployed.index, 'job'] = 'Unemployed'

# %%
df['job'].unique()
# Out:
# array(['Unskilled', 'Service', 'Retired', 'Professional', 'Unemployed',
#        'unknown', 'Student'], dtype=object)

# %% [markdown]
# Resulting in seven unique values<br><hr><br>

# %% [markdown]
# <h4>IMPUTATION</h4>

# %% [markdown]
# Now, in order to infer the unknown values in 'job' and 'education', we'll make use of the pandas function __pd.crosstab()__ to perform the cross-tabulation between 'job' and 'education'. Our hypothesis here is that, 'job' is influenced by the 'education' of an individual. We, therefore, will use  the job to predict the education.

# %%
x1 = pd.crosstab(df['job'],df['education'],  aggfunc='count')
x1.to_html('mytable')
x1
# Out:
# education     Basic  Degree   Mid  unknown
# job
# Professional    516    3830  1246      209
# Retired         675     520   421       98
# Service         732   11633  8155      611
# Student          39     213   456      166
# Unemployed      145     404   445       19
# Unskilled      4304     744  4768      496
# unknown          74      57    68      131

# %% [markdown]
# <br><h2> Splitting the unknown values in equal proportions among two highest features</h2><br>
# We will distribute the unknown values in the education feature among the two distibuted entities in the education feature which are greater in number according to the proportions they contribute to education.

# %%
#stores the index of the unknown values 
xx = df.loc[(df['education']=='unknown') & (df['job']=='Professional')][ 'education'].index

#this will evaluate the percentage factor on the basis of which we are going to distribute the unknown values
factor = round(sorted(x1.iloc[1,:].values.tolist(), reverse=True)[0]/float(sum(sorted(x1.iloc[1,:].values.tolist(), reverse=True)[:2])),2)

#evaluates the separating factor 
sep = round(len(xx)*factor)

for i in range(len(xx)):
    if i < sep:
        df.set_value(xx[i], 'education', 'Degree')
    else:
        df.set_value(xx[i], 'education', 'Mid')

# %% [markdown]
# The code for the rest of them is going to be same as demonstrated below

# %%
#using the same for Retired
xx = df.loc[(df['education']=='unknown') & (df['job']=='Retired')][ 'education'].index
factor = round(sorted(x1.iloc[2,:].values.tolist(), reverse=True)[0]/float(sum(sorted(x1.iloc[2,:].values.tolist(), reverse=True)[:2])),2)
sep = round(len(xx)*factor)
for i in range(len(xx)):
    if i < sep:
        df.set_value(xx[i], 'education', 'Basic')
    else:
        df.set_value(xx[i], 'education', 'Degree')


#using the same for Service
xx = df.loc[(df['education']=='unknown') & (df['job']=='Service')][ 'education'].index
factor = round(sorted(x1.iloc[3,:].values.tolist(), reverse=True)[0]/float(sum(sorted(x1.iloc[3,:].values.tolist(), reverse=True)[:2])),2)
sep = round(len(xx)*factor)
for i in range(len(xx)):
    if i < sep:
        df.set_value(xx[i], 'education', 'Degree')
    else:
        df.set_value(xx[i], 'education', 'Mid')
        
#using the same for Student
xx = df.loc[(df['education']=='unknown') & (df['job']=='Student')][ 'education'].index
factor = round(sorted(x1.iloc[4,:].values.tolist(), reverse=True)[0]/float(sum(sorted(x1.iloc[4,:].values.tolist(), reverse=True)[:2])),2)
sep = round(len(xx)*factor)
for i in range(len(xx)):
    if i < sep:
        df.set_value(xx[i], 'education', 'Mid')
    else:
        df.set_value(xx[i], 'education', 'Degree')

#using the same for Unemployed
xx = df.loc[(df['education']=='unknown') & (df['job']=='Unemployed')][ 'education'].index
factor = round(sorted(x1.iloc[5,:].values.tolist(), reverse=True)[0]/float(sum(sorted(x1.iloc[5,:].values.tolist(), reverse=True)[:2])),2)
sep = round(len(xx)*factor)
for i in range(len(xx)):
    if i < sep:
        df.set_value(xx[i], 'education', 'Mid')
    else:
        df.set_value(xx[i], 'education', 'Degree')

#using the same for Unskilled
xx = df.loc[(df['education']=='unknown') & (df['job']=='Unskilled')][ 'education'].index
factor = round(sorted(x1.iloc[6,:].values.tolist(), reverse=True)[0]/float(sum(sorted(x1.iloc[6,:].values.tolist(), reverse=True)[:2])),2)
sep = round(len(xx)*factor)
for i in range(len(xx)):
    if i < sep:
        df.set_value(xx[i], 'education', 'Mid')
    else:
        df.set_value(xx[i], 'education', 'Basic')

# %% [markdown]
# We will now crosstab between the education and job and see the difference

# %%
pd.crosstab(df['job'],df['education'],  aggfunc='count')
# Out:
# education     Basic  Degree   Mid  unknown
# job
# Professional    516    3947  1338        0
# Retired         733     560   421        0
# Service         732   12048  8351        0
# Student          39     293   542        0
# Unemployed      145     413   455        0
# Unskilled      4483     744  5085        0
# unknown          74      57    68      131

# %% [markdown]
# Now we will do the same for the unknown values in the job feature, lets first change the orientation.

# %%
x1 = pd.crosstab(df['education'],df['job'],  aggfunc='count')
x1
# Out:
# job        Professional  Retired  Service  Student  Unemployed  Unskilled  \
# education
# Basic               516      733      732       39         145       4483
# Degree             3947      560    12048      293         413        744
# Mid                1338      421     8351      542         455       5085
# unknown               0        0        0        0           0          0
#
# job        unknown
# education
# Basic           74
# Degree          57
# Mid             68
# unknown        131

# %% [markdown]
# For the people with Basic education, we see that a significant amount of people landed in the unskilled job category. Therefore, we will replace the unknwon values in this case with Unskilled category.

# %%
df.loc[(df['job'] == 'unknown') & (df['education']=='Basic'), 'job'] = 'Unskilled'

#using this code for degree
xx = df.loc[(df['job'] == 'unknown') & (df['education']=='Degree'), 'job'].index
factor = round(sorted(x1.iloc[2,:].values.tolist(), reverse=True)[0]/float(sum(sorted(x1.iloc[2,:].values.tolist(), reverse=True)[:2])),2)
sep = round(len(xx)*factor)
for i in range(len(xx)):
    if i < sep:
        df.set_value(xx[i], 'job', 'Service')
    else:
        df.set_value(xx[i], 'job', 'Professional')
        
#using this code for Mid
xx = df.loc[(df['job'] == 'unknown') & (df['education']=='Mid'), 'job'].index
factor = round(sorted(x1.iloc[3,:].values.tolist(), reverse=True)[0]/float(sum(sorted(x1.iloc[3,:].values.tolist(), reverse=True)[:2])),2)
sep = round(len(xx)*factor)
for i in range(len(xx)):
    if i < sep:
        df.set_value(xx[i], 'job', 'Service')
    else:
        df.set_value(xx[i], 'job', 'Unskilled')

# %% [markdown]
# We will now crosstab between the job and education again to see the difference.

# %%
x11 =pd.crosstab(df['education'],df['job'],  aggfunc='count')
x11.to_html('mytable')
x11
# Out:
# job        Professional  Retired  Service  Student  Unemployed  Unskilled  \
# education
# Basic               516      733      732       39         145       4557
# Degree             3969      560    12083      293         413        744
# Mid                1338      421     8419      542         455       5085
# unknown               0        0        0        0           0          0
#
# job        unknown
# education
# Basic            0
# Degree           0
# Mid              0
# unknown        131

# %% [markdown]
# <br><hr><br>

# %%
job_house=pd.crosstab(df['job'],df['housing'],  aggfunc='count')
job_loan=pd.crosstab(df['job'],df['loan'],  aggfunc='count')

# %% [markdown]
# Why are we doing cross-tabulation of House and Loan with job.Our hypothesis is that values in the housing feature should be in the proportion of each job category. Therefore, using the cross-tabulation between house and job it will give us an idea of the proportion with which the unknown values will be filled.

# %%
def job_house_fill(df,job_house):
    """Function for imputation via cross-tabulation to fill missing values for the 'housing' categorical feature"""
    jobs=df['job'].unique().tolist()
    house=["no","yes"]
    for j in jobs:
        ind=df[np.logical_and(np.array(df['housing']=='unknown'),np.array(df['job']==j))].index
        mask=np.random.rand(len(ind))<((job_house.loc[j]['no'])/(job_house.loc[j]['no']+job_house.loc[j]['yes']))
        ind1=ind[mask]
        ind2=ind[~mask]
        df.loc[ind1,"housing"]='no'
        df.loc[ind2,"housing"]='yes'
    return df

# %%
def job_loan_fill(df,job_loan):
    """Function for imputation via cross-tabulation to fill missing values for the 'loan' categorical feature"""
    jobs=jobs=df['job'].unique().tolist()
    loan=["no","yes"]
    for j in jobs:
        ind=df[np.logical_and(np.array(df['loan']=='unknown'),np.array(df['job']==j))].index
        mask=np.random.rand(len(ind))<((job_loan.loc[j]['no'])/(job_loan.loc[j]['no']+job_loan.loc[j]['yes']))
        ind1=ind[mask]
        ind2=ind[~mask]
        df.loc[ind1,"loan"]='no'
        df.loc[ind2,"loan"]='yes'
    return df

# %%
df=job_house_fill(df,job_house)

# %%
df=job_loan_fill(df,job_loan)

# %% [markdown]
# We will drop the 'duration' variable as the value of that will only be known at the end of the call. Therefore, at that time we will also know the outcome of the call. The 'duration' variable will lead to leakage in the data and the prediction model will not be realistic. Also 'day_of_week' variable is not giving any significant information so we will drop both the features.

# %%
df=df.drop(['duration','day_of_week'],axis=1)
cat_vars.remove('day_of_week') 

num_var.remove('duration')

# %% [markdown]
# ----
# Now, we will imputations on the marital status using the age data, thus for the values of unknown in marital if the age is greater then or equal to 40 we will replace those values by married and similarly if the age is less then 40 we  will replace the those unknnown values by single

# %%
df.loc[(df['marital']  == 'unknown') & (df['age']  >= 40), 'marital'] = 'married'
df.loc[(df['marital']  == 'unknown') & (df['age']  < 40), 'marital'] = 'single'

# %%
df_education_unknown = df[(df.education == 'unknown')]
df.loc[df_education_unknown.index, 'education'] = 'Degree'

df_job_unknown = df[(df.job == 'unknown')]
df.loc[df_job_unknown.index, 'job'] = 'Service'

# %% [markdown]
# ----
# Let us take a look on the categorical variables after they have been preprocessed
#
# ----

# %%
df.head()
# Out:
#    age        job  marital education  default housing loan    contact month  \
# 0   56  Unskilled  married     Basic       no      no   no  telephone   may
# 1   57    Service  married       Mid  unknown      no   no  telephone   may
# 2   37    Service  married       Mid       no     yes   no  telephone   may
# 3   40    Service  married     Basic       no      no   no  telephone   may
# 4   56    Service  married       Mid       no      no  yes  telephone   may
#
#    campaign  pdays  previous     poutcome  emp.var.rate  cons.price.idx  \
# 0         1    999         0  nonexistent           1.1          93.994
# 1         1    999         0  nonexistent           1.1          93.994
# 2         1    999         0  nonexistent           1.1          93.994
# 3         1    999         0  nonexistent           1.1          93.994
# 4         1    999         0  nonexistent           1.1          93.994
#
#    cons.conf.idx  euribor3m  nr.employed   y
# ...

# %% [markdown]
# Now, we will again look at the distribution of the of the categorical variables after they have been preprocessed.

# %%
for col in cat_vars:
    plt.figure(figsize=(10,4))
    draw_countplot(df,col)
    plt.title(col)
    plt.tight_layout()

# %% [markdown]
# <h1>Numerical variables</h1><br>

# %% [markdown]
# Here we will take a look at the numerical variables of our data set.

# %%
num_var
# Out:
# ['age',
#  'campaign',
#  'pdays',
#  'previous',
#  'emp.var.rate',
#  'cons.price.idx',
#  'cons.conf.idx',
#  'euribor3m',
#  'nr.employed']

# %% [markdown]
# We will use the __describe()__ method to summarize the data and get the better understanding of it.

# %%
df[num_var].describe()
# Out:
#                 age      campaign         pdays      previous  emp.var.rate  \
# count  41175.000000  41175.000000  41175.000000  41175.000000  41175.000000
# mean      40.020911      2.567796    962.512083      0.172848      0.082259
# std       10.418138      2.770318    186.820933      0.494661      1.571067
# min       17.000000      1.000000      0.000000      0.000000     -3.400000
# 25%       32.000000      1.000000    999.000000      0.000000     -1.800000
# 50%       38.000000      2.000000    999.000000      0.000000      1.100000
# 75%       47.000000      3.000000    999.000000      0.000000      1.400000
# max       98.000000     56.000000    999.000000      7.000000      1.400000
#
#        cons.price.idx  cons.conf.idx     euribor3m   nr.employed
# count    41175.000000   41175.000000  41175.000000  41175.000000
# mean        93.575288     -40.499349      3.622109   5167.100141
# std          0.578544       4.625310      1.734109     72.172435
# ...

# %% [markdown]
# __Missing Values__: Missing values are or 'NaN' are represented as '999' as mentioned in the U.C.I repository. We can see that majority of values for 'pdays' are missing.

# %%
pdat = pd.crosstab(index=df['pdays'],columns=df['poutcome'], values=df['age'], aggfunc='count')
pdat.to_html('mytable')

# %% [markdown]
# As we can see from the cross tablation of 'pdays' and 'poutcome',a large chunk of values from pdays are missing.And if we can see, '999' occurs nearly '35K' times when the poutcome is 'non-existent', which implies that it is because of the reason that the customer was never contacted before. We will replace the numerical variable 'pdays' with the categorical variable. The categories will be as follows:p_days_missing, pdays_less_5, pdays_bet_5_15, and pdays_greater_15.
#
# ----

# %%
def pdays_handler(df):
    #Add new categorical variables to our dataframe.
    df['pdays_missing'] = 0
    df['pdays_less_5'] = 0
    df['pdays_greater_15'] = 0
    df['pdays_bet_5_15'] = 0
    df['pdays_missing'][df['pdays']==999] = 1
    df['pdays_less_5'][df['pdays']<5] = 1
    df['pdays_greater_15'][(df['pdays']>15) & (df['pdays']<999)] = 1
    df['pdays_bet_5_15'][(df['pdays']>=5)&(df['pdays']<=15)]= 1
    df_dropped_pdays = df.drop('pdays', axis=1, inplace=True)

# %%
pdays_handler(df)
# Out:
# /usr/local/lib/python2.7/dist-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
# /usr/local/lib/python2.7/dist-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /usr/local/lib/python2.7/dist-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
# /usr/local/lib/python2.7/dist-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# ...

# %% [markdown]
# ----
# __Scaling Ecnomic Features__ we have various features in the dataset such as <i>'emp.var.rate', 'cons.price.idx','cons.conf.idx', 'euribor3m', 'nr.employed' </i> that needs to be scaled before using any machine learning algorithm. So we will define a function below that will be used to scale the features as shown below:
#
# ----

# %%
def scaling_ecnomic_features(df,cols_transform):
    scaler = StandardScaler()
    scaler.fit_transform(df[cols_transform])    
    df.loc[:, cols_transform] = scaler.fit_transform(df.loc[:, cols_transform])
    
    return df

# %%
from sklearn.preprocessing import StandardScaler
ecnomic_columns = ['emp.var.rate', 'cons.price.idx','cons.conf.idx', 'euribor3m', 'nr.employed']
df = scaling_ecnomic_features(df,ecnomic_columns)

# %% [markdown]
# Now lets take a look at our dataset:

# %%
df.sample(5)
# Out:
#        age        job  marital education  default housing loan    contact  \
# 26537   29    Service  married       Mid  unknown     yes  yes   cellular
# 6343    32  Unskilled   single       Mid       no     yes   no  telephone
# 32846   29    Service   single       Mid       no      no   no   cellular
# 37783   66    Retired  married     Basic  unknown     yes   no   cellular
# 25221   35  Unskilled  married     Basic       no      no   no   cellular
#
#       month  campaign       ...        emp.var.rate cons.price.idx  \
# 26537   nov         4       ...                -0.1         93.200
# 6343    may         2       ...                 1.1         93.994
# 32846   may         4       ...                -1.8         92.893
# 37783   aug         2       ...                -2.9         92.201
# 25221   nov         2       ...                -0.1         93.200
#
#        cons.conf.idx  euribor3m  nr.employed    y  pdays_missing pdays_less_5  \
# ...

# %% [markdown]
# Using __LabelEncoder__ to convert the output variables values into a form so that it can be used for further analysis:

# %%
from sklearn.preprocessing import LabelEncoder
output_transformer = LabelEncoder()
output_transformer.fit(list(df['y'].unique()))
df['y'] = output_transformer.transform(df['y'])

# %% [markdown]
# ----
# We will use the __one hot encoding___ method to convert rest of the categorical features into the numerical features so that they weill be used for further analysis. The total number of features have now jumped from 21 to 46.

# %%
df = pd.get_dummies(df)
df.shape
# Out:
# (41175, 47)

# %% [markdown]
# The correlation matrix is also given below as follows:

# %%
df.corr()
# Out:
#                            age  campaign  previous  emp.var.rate  \
# age                   1.000000  0.004569  0.024135     -0.000143
# campaign              0.004569  1.000000 -0.079116      0.150719
# previous              0.024135 -0.079116  1.000000     -0.420622
# emp.var.rate         -0.000143  0.150719 -0.420622      1.000000
# cons.price.idx        0.000235  0.128079 -0.203877      0.776412
# cons.conf.idx         0.130205 -0.013908 -0.050489      0.195683
# euribor3m             0.011228  0.135077 -0.454598      0.972319
# nr.employed          -0.016903  0.144075 -0.501627      0.907519
# y                     0.030120 -0.066267  0.230145     -0.298333
# pdays_missing        -0.034253  0.052520 -0.587309      0.270995
# pdays_less_5          0.029578 -0.038295  0.386189     -0.191306
# pdays_greater_15     -0.008045 -0.007096  0.097714     -0.030610
# pdays_bet_5_15        0.021358 -0.034868  0.423772     -0.186885
# ...

# %% [markdown]
# We will generate a __heatmap__ of the data we have now so that we will get a better understanding how the data is correlated to each other.

# %%
plt.figure(figsize=(16, 18))
sns.heatmap(df.corr(),cmap='PiYG')

# %% [markdown]
# ----
# # Machine Learning
# ----
# Various packages used below are because of the following reasons:
# - __time__ to evaluate the excution time.
# - __cross_val_score__ for evaluation of cross validation accuracy
# - __StratifiedKFold__ We will use this method for as cross validation parameter in the above function
# - __train_test_split__ this will be used to split the data into test and train data.
# - __accuracy_score__ this will be used to evaluate the general accuracy of the classifier

# %%
import time
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report

skf = StratifiedKFold(n_splits=20, random_state=0)

target = df['y']
features = df.drop('y',axis=1)

d_train, d_test, l_train, l_test = train_test_split(features, target,test_size=0.3, random_state=23)

# %% [markdown]
# #### 1) Desision Tree Classifier
# We will use this data in our Machine learning algorithm and print out the accuracy score as follows. Here we will use the Decision tree Classifier as shown below. We have used __StratifiedKFold()__ as cross validation method for checking the cross validation score.

# %%
from sklearn.tree import DecisionTreeClassifier

start_time = time.time()

clf_ftr = DecisionTreeClassifier(criterion='entropy',min_samples_split = 9,max_depth=6,random_state=23)
clf_ftr = clf_ftr.fit(d_train, l_train)

predicted = clf_ftr.predict(d_test)
scores = cross_val_score(clf_ftr, features, target, cv=skf)

print("Decision Tree Classifier Accuracy: {0:.2%}".format(accuracy_score(predicted, l_test)))
print("Cross validation score: {0:.2%}".format(np.mean(scores)))
print("Execution time: {0:.5} seconds \n".format(time.time()-start_time))
# Out:
# Decision Tree Classifier Accuracy: 89.67%
# Cross validation score: 72.83%
# Execution time: 2.7611 seconds

# %% [markdown]
# #### 2) Logistic Regression
# Now we will use the Logistic Regression as shown below using the same approach.
# <br>

# %%
from sklearn.linear_model import LogisticRegression

start_time = time.time()

lrc = LogisticRegression()
lrc.fit(d_train, l_train)

predicted = lrc.predict(d_test)
scores = cross_val_score(lrc, features, target, cv=skf)

print("Logistic Regression Accuracy: {0:.2%}".format(accuracy_score(predicted, l_test)))
print("Cross validation score: {0:.2%}".format(np.mean(scores)))
print("Execution time: {0:.5} seconds \n".format(time.time()-start_time))
# Out:
# Logistic Regression Accuracy: 89.82%
# Cross validation score: 85.26%
# Execution time: 8.1051 seconds

# %% [markdown]
# #### 3) Random Forest Classifier
# Same approach will be used for Random Forest Classifier.
# <br>

# %%
from sklearn.ensemble import RandomForestClassifier

start_time = time.time()

rfc = RandomForestClassifier(n_estimators=10,  max_depth=4, min_samples_split=9)
rfc.fit(d_train, l_train)

predicted = rfc.predict(d_test)
scores = cross_val_score(rfc, features, target, cv=skf)

print("Random Forest Classifier: {0:.2%}".format(accuracy_score(predicted, l_test)))
print("Cross validation score: {0:.2%}".format(np.mean(scores)))
print("Execution time: {0:.5} seconds \n".format(time.time()-start_time))
# Out:
# /usr/local/lib/python2.7/dist-packages/sklearn/ensemble/weight_boosting.py:29: DeprecationWarning: numpy.core.umath_tests is an internal NumPy module and should not be imported. It will be removed in a future NumPy release.
#   from numpy.core.umath_tests import inner1d
# Random Forest Classifier: 89.65%
# Cross validation score: 84.11%
# Execution time: 4.239 seconds

# %% [markdown]
# #### 4)Ada Boost Classifier<br>

# %%
from sklearn.ensemble import AdaBoostClassifier

start_time = time.time()

ad = AdaBoostClassifier(base_estimator=rfc, n_estimators=5)
ad.fit(d_train, l_train)

predicted = ad.predict(d_test)
scores = cross_val_score(ad, features, target, cv=skf)

print("Ada Boost Classifier Accuracy: {0:.2%}".format(accuracy_score(predicted, l_test)))
print("Cross validation score: {0:.2%}".format(np.mean(scores)))
print("Execution time: {0:.5} seconds \n".format(time.time()-start_time))

# %% [markdown]
# #### 5) Support Vector Machine
# <br>

# %%
from sklearn.svm import LinearSVC

start_time = time.time()

sclf = LinearSVC()
sclf.fit(d_train, l_train)

predicted = sclf.predict(d_test)
scores = cross_val_score(sclf, features, target, cv=skf)

print("Support Vector Machine: {0:.2%}".format(accuracy_score(predicted, l_test)))
print("Cross validation score: {0:.2%}".format(np.mean(scores)))
print("Execution time: {0:.5} seconds \n".format(time.time()-start_time))

# %% [markdown]
# #### 6) K Nearest Neighbour Classifier
# <br>

# %%
from sklearn.neighbors import KNeighborsClassifier

start_time = time.time()

k_clf = KNeighborsClassifier()
k_clf.fit(d_train, l_train)

prediction = k_clf.predict(d_test)
scores = cross_val_score(k_clf,features, target, cv=skf)

print("Logistic Regression Accuracy: {0:.2%}".format(accuracy_score(predicted, l_test)))
print("Cross validation score: {0:.2%}".format(np.mean(scores)))
print("Execution time: {0:.5} seconds \n".format(time.time()-start_time))

# %% [markdown]
# #### 7) Extra Tree Classifier
# <br>

# %%
from sklearn.ensemble import ExtraTreesClassifier

start_time = time.time()

ex_clf = ExtraTreesClassifier()
ex_clf.fit(d_train, l_train)

prediction = ex_clf.predict(d_test)
scores = cross_val_score(ex_clf,features, target, cv=skf)

print("Logistic Regression Accuracy: {0:.2%}".format(accuracy_score(predicted, l_test)))
print("Cross validation score: {0:.2%}".format(np.mean(scores)))
print("Execution time: {0:.5} seconds \n".format(time.time()-start_time))

# %% [markdown]
# #### Voting Classifier
# <br>

# %%
from sklearn.ensemble import VotingClassifier

start_time = time.time()

vclf1 = VotingClassifier(estimators=[('rfc_1', ad), ('log_reg', lrc), ('des_tree', clf_ftr)], voting='soft')
vclf1.fit(d_train, l_train)

predicted = vclf1.predict(d_test)
scores = cross_val_score(vclf1,features, target, cv=skf)

print("Voting Classifier Accuracy: {0:.2%}".format(accuracy_score(predicted, l_test)))
print("Cross validation score: {0:.2%}".format(np.mean(scores)))
print("Execution time: {0:.5} seconds \n".format(time.time()-start_time))

# %% [markdown]
# ## Feature Selection
# In this module we will use __Select by Model__ specifically Decision Tree Forest Method for selecting only those features which carry more information by using the __feature_importances__ method. This will help is reducing the time complexity as well as some undesirable noise.

# %%
#these two lists contain the feature score and feature name which contibutes to the specific score
ftr_scr =[]
ftr_info = []


for z in np.arange(0.001,.5,.001):
    imp = []
    #print(z)
    for i,x in zip(clf_ftr.feature_importances_,features.columns.values):
        if i >= z:            
            imp.append(i)
    ftr_scr.append(100*sum(imp))
    ftr_info.append(len(imp))

plt.figure(figsize=(12,8))
plt.scatter(x=ftr_scr,y=ftr_info, c="r", alpha=1, marker='o', s = 200)
plt.title("Feature vs Importance Graph")
plt.xlabel("Information gain")
plt.ylabel("Number of features")
plt.grid()
plt.show()

# %% [markdown]
# Now we will use that coefficient to select the minimum number of features with maximum information gain.Here we have used the coefficient of 0.001 and selected about 15 features which carry 99.48% information.

# %%
imp = []
imp_cols = []
for i,x in zip(clf_ftr.feature_importances_,features.columns.values):
    
    if i >= 0.01:
        print(i,x)
        imp.append(i)
        imp_cols.append(x)
print(sum(imp))
print(len(imp))

# %%
plat = df[imp_cols]
plat['y']= target
sns.heatmap(plat.corr())

# %% [markdown]
# ----
# #### Machine Learning on Selected Features
# ----
# We will again use the train_test_split method wo split the data with only selected features.

# %%
d_train, d_test, l_train, l_test = train_test_split(features[imp_cols], target,test_size=0.3, random_state=23)

# %% [markdown]
# ----
# #### 1) Decision Tree Classifier (FS)

# %%
start_time = time.time()

clf_ftr = DecisionTreeClassifier(criterion='entropy',min_samples_split = 9,max_depth=6,random_state=23)
clf_ftr = clf_ftr.fit(d_train, l_train)

predicted = clf_ftr.predict(d_test)
scores = cross_val_score(clf_ftr, features, target, cv=skf)

print("Decision Tree Classifier Accuracy: {0:.2%}".format(accuracy_score(predicted, l_test)))
print("Cross validation score: {0:.2%}".format(np.mean(scores)))
print("Execution time: {0:.5} seconds \n".format(time.time()-start_time))

# %% [markdown]
# #### 2) Logistic Regression (FS)

# %%
start_time = time.time()

lrc = LogisticRegression()
lrc.fit(d_train, l_train)

predicted = lrc.predict(d_test)
scores = cross_val_score(lrc, features, target, cv=skf)

print("Logistic Regression Accuracy: {0:.2%}".format(accuracy_score(predicted, l_test)))
print("Cross validation score: {0:.2%}".format(np.mean(scores)))
print("Execution time: {0:.5} seconds \n".format(time.time()-start_time))

# %% [markdown]
# #### 3) Random Forest Classifier (FS)
# <br>

# %%
start_time = time.time()

rfc = RandomForestClassifier(n_estimators=10,  max_depth=4, min_samples_split=9)
rfc.fit(d_train, l_train)

predicted = rfc.predict(d_test)
scores = cross_val_score(rfc, features, target, cv=skf)

print("Random Forest Classifier: {0:.2%}".format(accuracy_score(predicted, l_test)))
print("Cross validation score: {0:.2%}".format(np.mean(scores)))
print("Execution time: {0:.5} seconds \n".format(time.time()-start_time))

# %% [markdown]
# #### 4)Ada Boost Classifier (FS)
# <br>

# %%
start_time = time.time()

ad = AdaBoostClassifier(base_estimator=rfc, n_estimators=5)
ad.fit(d_train, l_train)

predicted = ad.predict(d_test)
scores = cross_val_score(ad, features, target, cv=skf)

print("Ada Boost Classifier Accuracy: {0:.2%}".format(accuracy_score(predicted, l_test)))
print("Cross validation score: {0:.2%}".format(np.mean(scores)))
print("Execution time: {0:.5} seconds \n".format(time.time()-start_time))

# %% [markdown]
# #### 5) Support Vector Machine (FS)
# <br>

# %%
start_time = time.time()

sclf = LinearSVC()
sclf.fit(d_train, l_train)

predicted = sclf.predict(d_test)
scores = cross_val_score(sclf, features, target, cv=skf)

print("Support Vector Machine: {0:.2%}".format(accuracy_score(predicted, l_test)))
print("Cross validation score: {0:.2%}".format(np.mean(scores)))
print("Execution time: {0:.5} seconds \n".format(time.time()-start_time))

# %% [markdown]
# #### 6) K Nearest Neighbour Classifier(FS)
# <br>

# %%
start_time = time.time()

k_clf = KNeighborsClassifier()
k_clf.fit(d_train, l_train)

prediction = k_clf.predict(d_test)
scores = cross_val_score(k_clf,features, target, cv=skf)

print("K-Nearest Neighbour Accuracy: {0:.2%}".format(accuracy_score(predicted, l_test)))
print("Cross validation score: {0:.2%} (+/- {1:.2%})".format(np.mean(scores), np.std(scores)*2))
print("Execution time: {0:.5} seconds \n".format(time.time()-start_time))

# %% [markdown]
# #### 7) Extra Tree Classifier (FS)
# <br>

# %%
start_time = time.time()

ex_clf = ExtraTreesClassifier()
ex_clf.fit(d_train, l_train)

prediction = ex_clf.predict(d_test)
scores = cross_val_score(ex_clf,features, target, cv=skf)

print("Logistic Regression Accuracy: {0:.2%}".format(accuracy_score(predicted, l_test)))
print("Cross validation score: {0:.2%} (+/- {1:.2%})".format(np.mean(scores), np.std(scores)*2))
print("Execution time: {0:.5} seconds \n".format(time.time()-start_time))

# %% [markdown]
# #### Voting Classifier (FS)
# <br>

# %%
start_time = time.time()

vclf1 = VotingClassifier(estimators=[('rfc_1', ad), ('log_reg', lrc), ('des_tree', clf_ftr)], voting='soft')
vclf1.fit(d_train, l_train)

predicted = vclf1.predict(d_test)
scores = cross_val_score(vclf1,features, target, cv=skf)

print("Voting Classifier Accuracy: {0:.2%}".format(accuracy_score(predicted, l_test)))
print("Cross validation score: {0:.2%} (+/- {1:.2%})".format(np.mean(scores), np.std(scores)*2))
print("Execution time: {0:.5} seconds \n".format(time.time()-start_time))

# %% [markdown]
# ![Image error](img/table_accuracy.png)

# %% [markdown]
# ----
# ----
# ----
# ----

# %% [markdown]
# ## For New Data
# <br>

# %%
def convertInputFeatures(df):
    #Grouping Education variable
    df_basic_ed = df[(df.education == 'basic.4y') | (df.education == 'basic.6y') | (df.education == 'illiterate')]
    df_mid_ed = df[(df.education == 'basic.9y') | (df.education == 'high.school')]
    df_degree_ed = df[(df.education == 'professional.course') | (df.education == 'university.degree')]
     
    df.loc[df_basic_ed.index, 'education'] = 'Basic'
    df.loc[df_mid_ed.index, 'education'] = 'Mid'
    df.loc[df_degree_ed.index, 'education'] = 'Degree'
    
     
    df_unskilled = df[(df.job == 'blue-collar') | (df.job == 'housemaid')]
    df_service = df[(df.job == 'admin.') | (df.job == 'services') | (df.job == 'technician')]
    df_professional = df[(df.job == 'entrepreneur') | (df.job == 'self-employed') | (df.job == 'management')]
    df_student = df[(df.job == 'student')]
    df_retired = df[(df.job == 'retired')]
    df_unemployed = df[(df.job == 'unemployed')]      
        
    df.loc[df_unskilled.index, 'job'] = 'Unskilled'
    df.loc[df_service.index, 'job'] = 'Service'
    df.loc[df_professional.index, 'job'] = 'Professional'
    df.loc[df_student.index, 'job'] = 'Student'
    df.loc[df_retired.index, 'job'] = 'Retired'
    df.loc[df_unemployed.index, 'job'] = 'Unemployed'


    
    #Removing insignificant variables
    df.drop(['day_of_week'],axis=1,inplace=True)
    df.drop('duration',axis=1,inplace=True)
    
    df_loan_unknown = df[(df.loan == 'unknown')]
    df.loc[df_loan_unknown.index, 'loan'] = 'no'

    df_housing_unknown = df[(df.housing == 'unknown')]
    df.loc[df_housing_unknown.index, 'housing'] = 'yes'

    return df

# %%
cols = ["age","job","marital","education","default","housing","loan","contact","month","day_of_week","duration","campaign","pdays","previous","poutcome","emp.var.rate","cons.price.idx","cons.conf.idx","euribor3m","nr.employed",'y']

dtest = pd.read_csv('/home/future/Documents/Project data set/bank-additional/bank-additional/bank_user.txt',delimiter= ';')

dtest.columns = cols
tt2 = dtest.drop('y',axis=1,inplace=True)

# %%
dtest = convertInputFeatures(dtest)

# %%
dtest = pd.get_dummies(dtest)

# %%
pdays_handler(dtest)
# Out:
# /usr/local/lib/python2.7/dist-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
# /usr/local/lib/python2.7/dist-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /usr/local/lib/python2.7/dist-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
# /usr/local/lib/python2.7/dist-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# ...

# %%
for i in df.columns.tolist():
    if i in dtest.columns.tolist():
        pass
    else:
        dtest[i] = 0

# %%
dtest.drop('y',axis = 1,inplace=True)

# %%
dtest.shape
# Out:
# (12, 46)

# %%
test_data = np.asanyarray(dtest)

# %%
output_transformer.inverse_transform(lrc.predict(test_data))
# Out:
# /usr/local/lib/python2.7/dist-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# array(['yes', 'no', 'yes', 'no', 'yes', 'yes', 'yes', 'no', 'yes', 'no',
#        'yes', 'no'], dtype='|S3')
